# %%
import asyncio
import aiohttp

# %%
async def get_data(i: int, endpoint: str):
    print(f'Начал выполнение: {i}')
    url = f'http://127.0.0.1:8000/{endpoint}/{i}'
    async with aiohttp.ClientSession() as session:
        async with session.get(url) as resp:
            print(f'Закончил выполнение: {i}')

# %%
await get_data(1, 'sync')
# Out:
# Начал выполнение: 1
# Закончил выполнение: 1

# %%
await get_data(1, 'async')
# Out:
# Начал выполнение: 1
# Закончил выполнение: 1

# %%
await asyncio.gather(*[get_data(i, 'sync') for i in range(100)])
# Out:
# Начал выполнение: 0
# Начал выполнение: 1
# Начал выполнение: 2
# Начал выполнение: 3
# Начал выполнение: 4
# Начал выполнение: 5
# Начал выполнение: 6
# Начал выполнение: 7
# Начал выполнение: 8
# Начал выполнение: 9
# Начал выполнение: 10
# Начал выполнение: 11
# Начал выполнение: 12
# Начал выполнение: 13
# Начал выполнение: 14
# Начал выполнение: 15
# Начал выполнение: 16
# Начал выполнение: 17
# Начал выполнение: 18
# Начал выполнение: 19
# Начал выполнение: 20
# Начал выполнение: 21
# Начал выполнение: 22
# Начал выполнение: 23
# Начал выполнение: 24
# Начал выполнение: 25
# Начал выполнение: 26
# Начал выполнение: 27
# Начал выполнение: 28
# Начал выполнение: 29
# Начал выполнение: 30
# Начал выполнение: 31
# Начал выполнение: 32
# Начал выполнение: 33
# Начал выполнение: 34
# Начал выполнение: 35
# Начал выполнение: 36
# Начал выполнение: 37
# Начал выполнение: 38
# Начал выполнение: 39
# Начал выполнение: 40
# Начал выполнение: 41
# Начал выполнение: 42
# ...

# %%
await asyncio.gather(*[get_data(i, 'async') for i in range(100)])
# Out:
# Начал выполнение: 0
# Начал выполнение: 1
# Начал выполнение: 2
# Начал выполнение: 3
# Начал выполнение: 4
# Начал выполнение: 5
# Начал выполнение: 6
# Начал выполнение: 7
# Начал выполнение: 8
# Начал выполнение: 9
# Начал выполнение: 10
# Начал выполнение: 11
# Начал выполнение: 12
# Начал выполнение: 13
# Начал выполнение: 14
# Начал выполнение: 15
# Начал выполнение: 16
# Начал выполнение: 17
# Начал выполнение: 18
# Начал выполнение: 19
# Начал выполнение: 20
# Начал выполнение: 21
# Начал выполнение: 22
# Начал выполнение: 23
# Начал выполнение: 24
# Начал выполнение: 25
# Начал выполнение: 26
# Начал выполнение: 27
# Начал выполнение: 28
# Начал выполнение: 29
# Начал выполнение: 30
# Начал выполнение: 31
# Начал выполнение: 32
# Начал выполнение: 33
# Начал выполнение: 34
# Начал выполнение: 35
# Начал выполнение: 36
# Начал выполнение: 37
# Начал выполнение: 38
# Начал выполнение: 39
# Начал выполнение: 40
# Начал выполнение: 41
# Начал выполнение: 42
# ...
